# %% [markdown]
# # while loop

# %%
flag = True
while flag:
    print("inside loop")
    flag = False
print("outside")
# Out:
# inside loop
# outside

# %%
count = 0 
while count < 5:
    print("inside")
    count = count + 1
print("outside")
# Out:
# inside
# inside
# inside
# inside
# inside
# outside

# %% [markdown]
# # operators

# %%
6/2 #float division
# Out:
# 3.0

# %%
6//2 #integar division
# Out:
# 3

# %%
6.8/2
# Out:
# 3.4

# %%
6.8//2
# Out:
# 3.0

# %%
4.5/2
# Out:
# 2.25

# %%
4.5//2
# Out:
# 2.0

# %%
4/2.5
# Out:
# 1.6

# %%
4//2.5
# Out:
# 1.0

# %%
"3" * 2
# Out:
# '33'

# %%
"3" * 2
# Out:
# '33'

# %%
type("3" * 2)
# Out:
# str

# %%
a = 10
b = 2

# %%
a == b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
b < a
# Out:
# True

# %%
b > a
# Out:
# False

# %%
a < b
# Out:
# False

# %%
a = -a

# %%
a > b
# Out:
# False

# %%
x = 1.1 + 2.2
print(x)
x == 3.3
# Out:
# 3.3000000000000003
# False

# %%
tolerance = 0.00001
x = 1.1 + 2.2
abs(x - 3.3) < tolerance
# '''abs() returns absolute value. If the absolute value of
# the difference between the two numbers is less than the 
# specified tolerance, they are close enough to one another 
# to be considered equal.'''
# Out:
# True

# %%
x = 5 
x < 10
# Out:
# True

# %%
callable(x)
# Out:
# False

# %%
t = x > 10
t
# Out:
# False

# %%
callable(t)
# Out:
# False

# %%
callable(len)
# Out:
# True

# %%
not callable(x)
# Out:
# True

# %%
5 > 3 or 3> 5
# Out:
# True

# %%
5 > 3 and 3 > 5
# Out:
# False

# %%
x = 5
not x > 10
# Out:
# True

# %%
not 5 > 3
# Out:
# False

# %%
a is x
# Out:
# False

# %%
a is not x
# Out:
# True

# %%
1 + 2 ** 3 * 4
# Out:
# 33

# %% [markdown]
# # .format()

# %%
f = 4.5678
e = 6.5789
print('({:.2}, {:.2})'.format(f, e))
# Out:
# (4.6, 6.6)

# %%
f = 4.5678
e = 6.5789
print('({:.3}, {})'.format(f, e))
# Out:
# (4.57, 6.5789)

# %%
a = 13.456

# %%
print("%.2f" % a)
# Out:
# 13.46

# %%
g = float("{0:.2f}".format(a))
g
# Out:
# 13.46

# %%
c = format(a , '.2f')
c
# Out:
# '13.46'

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\aqadi',
#  'C:\\Users\\aqadi\\Anaconda3\\python37.zip',
#  'C:\\Users\\aqadi\\Anaconda3\\DLLs',
#  'C:\\Users\\aqadi\\Anaconda3\\lib',
#  'C:\\Users\\aqadi\\Anaconda3',
#  '',
#  'C:\\Users\\aqadi\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\aqadi\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\aqadi\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\aqadi\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\aqadi\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\aqadi\\.ipython']

# %%
count=0  
while count<5:
    print('Inside loop')
    count = count+1  
    if count == 3:
        break  
print('Outside loop')
# Out:
# Inside loop
# Inside loop
# Inside loop
# Outside loop

# %%
count=0  
while count<5:
    print('Inside loop')
    count = count+1  
    if count == 3:
        pass  
print('Outside loop')
# Out:
# Inside loop
# Inside loop
# Inside loop
# Inside loop
# Inside loop
# Outside loop

# %%
count=0  
while count<5:
    print('Inside loop')
    count = count+1  
    if count == 3:
        continue
print('Outside loop')
# Out:
# Inside loop
# Inside loop
# Inside loop
# Inside loop
# Inside loop
# Outside loop

# %%
for count in range(1, 13):
    if count == 5:
        print(count)
        continue
print('finished')
# Out:
# 5
# finished

# %%
for count in range(1, 13):
    if count == 5:
        break
    print(count)
print('Finished')
# Out:
# 1
# 2
# 3
# 4
# Finished

# %%
for count in range(1, 13):
    if count == 5:
        continue
    print(count)
print('Finished')
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# Finished

# %%
def m2():     
    print('the') 
    
def m3():     
    print('sat on') 
    m2() 
def m1():   
    m2()     
    print('cat')    
    m3()   
    print('mat') 
m1()
# Out:
# the
# cat
# sat on
# the
# mat

# %%
def print_times_table(times_value):
    count = 1 
    while count < 13:         
        result = count * times_value        
        print(count, 'times', times_value, 'equals', result)         
        count = count + 1

# %%
print_times_table(5)
# Out:
# 1 times 5 equals 5
# 2 times 5 equals 10
# 3 times 5 equals 15
# 4 times 5 equals 20
# 5 times 5 equals 25
# 6 times 5 equals 30
# 7 times 5 equals 35
# 8 times 5 equals 40
# 9 times 5 equals 45
# 10 times 5 equals 50
# 11 times 5 equals 55
# 12 times 5 equals 60

# %%
print_times_table(7)
# Out:
# 1 times 7 equals 7
# 2 times 7 equals 14
# 3 times 7 equals 21
# 4 times 7 equals 28
# 5 times 7 equals 35
# 6 times 7 equals 42
# 7 times 7 equals 49
# 8 times 7 equals 56
# 9 times 7 equals 63
# 10 times 7 equals 70
# 11 times 7 equals 77
# 12 times 7 equals 84

# %%
print_times_table(14)
# Out:
# 1 times 14 equals 14
# 2 times 14 equals 28
# 3 times 14 equals 42
# 4 times 14 equals 56
# 5 times 14 equals 70
# 6 times 14 equals 84
# 7 times 14 equals 98
# 8 times 14 equals 112
# 9 times 14 equals 126
# 10 times 14 equals 140
# 11 times 14 equals 154
# 12 times 14 equals 168

# %%
print_times_table(56)
# Out:
# 1 times 56 equals 56
# 2 times 56 equals 112
# 3 times 56 equals 168
# 4 times 56 equals 224
# 5 times 56 equals 280
# 6 times 56 equals 336
# 7 times 56 equals 392
# 8 times 56 equals 448
# 9 times 56 equals 504
# 10 times 56 equals 560
# 11 times 56 equals 616
# 12 times 56 equals 672

# %%
print_times_table('six')
# Out:
# 1 times six equals six
# 2 times six equals sixsix
# 3 times six equals sixsixsix
# 4 times six equals sixsixsixsix
# 5 times six equals sixsixsixsixsix
# 6 times six equals sixsixsixsixsixsix
# 7 times six equals sixsixsixsixsixsixsix
# 8 times six equals sixsixsixsixsixsixsixsix
# 9 times six equals sixsixsixsixsixsixsixsixsix
# 10 times six equals sixsixsixsixsixsixsixsixsixsix
# 11 times six equals sixsixsixsixsixsixsixsixsixsixsix
# 12 times six equals sixsixsixsixsixsixsixsixsixsixsixsix

# %%
print_times_table("three")
# Out:
# 1 times three equals three
# 2 times three equals threethree
# 3 times three equals threethreethree
# 4 times three equals threethreethreethree
# 5 times three equals threethreethreethreethree
# 6 times three equals threethreethreethreethreethree
# 7 times three equals threethreethreethreethreethreethree
# 8 times three equals threethreethreethreethreethreethreethree
# 9 times three equals threethreethreethreethreethreethreethreethree
# 10 times three equals threethreethreethreethreethreethreethreethreethree
# 11 times three equals threethreethreethreethreethreethreethreethreethreethree
# 12 times three equals threethreethreethreethreethreethreethreethreethreethreethree

# %%
s = 'foobar'
s[::-1][::-5]
# Out:
# 'fr'

# %%
s[::5]
# Out:
# 'fr'

# %%
s[::-1][-1] + s[len(s)-1]
# Out:
# 'fr'

# %%
s[::-5]
# Out:
# 'rf'

# %%
s[0]+s[-1]
# Out:
# 'fr'

# %%
import statistics

# %%
if none:
    print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-169-191ee88eb930> in <module>
# ----> 1 if none:
#       2     print("hello")
#
# NameError: name 'none' is not defined

# %%
s = [1 , 2 , 3]

# %%
s
# Out:
# [1, 2, 3]

# %%
def printLine(text):
  print(text, 'is awesome.')

printLine('Python')
# Out:
# Python is awesome.

# %%
def greetPerson(*name):
  print('Hello', name)

greetPerson('Frodo', 'Sauron')
# Out:
# Hello ('Frodo', 'Sauron')

# %%
language = ['P', 'y', 't', 'h', 'o', 'n']
print(language[:-4])
# Out:
# ['P', 'y']

# %%
print((1, 2) + (3, 4))
# Out:
# (1, 2, 3, 4)

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.pylint.d',
#  '.spyder-py3',
#  '.vscode',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'classes.ipynb',
#  'Contacts',
#  'Cookies',
#  'Creative Cloud Files',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  "dua's work.ipynb",
#  'excer 1 code 1.py',
#  'Favorites',
#  'get-pip.py',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Microsoft python test .ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  "nimrah's qstn.ipynb",
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{523b037c-9074-11e8-87e3-28c63f813615}.TM.blf',
#  'NTUSER.DAT{523b037c-9074-11e8-87e3-28c63f813615}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{523b037c-9074-11e8-87e3-28c63f813615}.TMContainer00000000000000000002.regtrans-ms',
# ...

# %%
list1=[1,2,3]
x=list1*3
x
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
